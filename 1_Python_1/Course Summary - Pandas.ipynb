# %% [markdown]
# ## pandas
# 1. import pandas as pd
# 2. Used for managing data. imagine it like excel
# 2. Has series and dataframe data types.
#     2.1 Series - columns
#         2.1.a - data
#         2.1.b - index
#     2.2 Dataframe - table
#         2.2.a - data (list of series)
#         2.2.b - axis (0 - row, 1 - col)
#
#
# ### Series
# #### Creation
# 1. From List:    myseries1 = pd.Series(data=[1,2,3])
# 2. From Arrays:  myseries2 = pd.Series(data=np.array([1,2,3]))
# 3. From Dictionary: myseries3 = pd.Series(data={"One": 1, "Two": 2, "Three", 3 })
# #### Labelling Index
# 1. myseries4 = pd.Series(data=[1,2,3], index=["One", "Two", "Three"])
#
# #### Access
# 1. By Index: myseries4[1]
# 2. By labelled Index: myseries4['Two']
#
# #### Arithmetic
# myseries5 = myseries1+myseries2
#
# ### Dataframe
#
# #### Creation
# 1. np.DataFrame(np.array[[1,1,1], [2,2,2]])
# 2. concat: pd.concat([myseries1, myseries1], axis=1, sort=False)
#
# #### Labelling Index
# 1. Row label - np.DataFrame(np.array[[1,1,1], [2,2,2]], index=["row 1", "row 2"])
# 2. Col label - np.DataFrame(np.array[[1,1,1], [2,2,2]], index=["row 1", "row 2"], columns=['col 1', 'col2'])
# #### Access
# 1. By Col label: df['col 1']
# 2. By Col label list: df[['col1', 'col2']]
# 3. By col index: df[0]
# 4. By Row label: df.loc['row 1']
# 5. By Row Index: df.iloc[0]
# 6. By Cell Label: df.loc[['row 1', 'row2'], ['col 1', 'col 2']]
# 7. By cell index: df[0][0]
#
# #### Schema changes
# 1. Add col - df['new col'] = [1,2]
# 2. drop col - df.drop('col 1', axis = 1)
# 3. drop row - df.drop('row 1', axis = 0)
# 4. del df8['color']
# 5. Convert row label to series - df.reset_index(inplace=True)
# 6. Convert series to row label - df.set_index('col 1', inplace=True)
# 7. concat -
#     6.1 row wise - pd.concat([df1, df2], axis=0, sort=False)
#     6.2 col wise - pd.concat([df1, df2], axis=1, dort=False)
# 8. merge - combines df using column's values to identify entries
#     pd.merge(df1, df2, how='outer', on='customer') ##outer (union), inner, left, right
# 9. join - combines df using the index to identify common entries
#     df1.join(df2, how='outer') ##outer (union), inner, left, right
#
# #### Functions
# 1. df['col1'].unique()
# 2. df['col1'].value_counts() -> count of each item in the column
# 3. df.mean() or df['col1'].mean()
# 4. df.columns
# 5. apply - works on each item on the series
#     df.apply(mycustomfn); def mycustomfn(s).....
# 6. applymap - works on multiple series
#     d2 = df[['distance', 'sales']]
#     df.applymap(mycustomfn) #  throws error when you use function that aggregrate functions
# 7. Group by
#     grouped_data = df14.groupby('customer')
#     grouped_data.describe()
#     grouped_data.mean()
#
# #### Fiter by Logical operation
# 1. df[df>0]
# 2. df[(df['customer']!=105) && (df['color']!='green')]
#
# #### Saving/loading to/from txt and excel
# 1. df8.to_csv('df8.csv', index=True)
# 2. new_df8 = pd.read_csv('df8.csv', index_col=0)
# 3. df8.to_excel('df8.xlsx', index=False, sheet_name='first sheet')
# 4. newer_df8 = pd.read_excel('df8.xlsx', sheet_name='first sheet')
